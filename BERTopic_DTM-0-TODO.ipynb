# %% [markdown]
# ## TODO

# %%
# Commentaires, crise, évolution hiérarchique ?
# Nombre de commentaires, évolution de la diversité au cours du temps, sentiment analysis sur les commentaires ?
# Statistiques descriptives

# Aspect interactif: commentaires
# Aspect temporel: blog, évolution, crise financière
# Posner 2nd blog (theatlantic.com) (?)

# Meilleure classification des topics
# Co-évolution des topics individuels (pas catégories) au fil du temps
# Comparer topics individuels Becker-Posner sur modèle global
# Commentaires public: évolution des position des gens (séparation posner/becker), commentaires/post

# Tester modèle avec posts + commentaires utilisateurs (éventuellement Posner/Becker)
# Stats descriptives:
# 1) P-B temporal development (par période, no comments), activité globale
# 2) Posner vs Becker (all Posner vs all Becker, no comments), structure des topics
# 3) Interaction avec public (Posner-Becker + comments pool vs pool of comments) -> activité des commentaires, quels sujets
# font des vagues etc.

# Samuel: Papier sur modèles
# Maxime/Miguel: papier commun -> quel axe, quelle revue (?)

# Sentiment analysis per user (commentator)
# Evolution des commentateurs
# Leader vs follower: nb comments etc
# Most common commentators per author (topic?)
# Anonymous, period with no comments
# 9 à 14h MSH
# Journal of economic methodology
